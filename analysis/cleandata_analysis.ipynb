# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import json

# %%
#provide the path of csv file
path = "../Resources/Programming_Language_data.csv"

# %%
#read csv_file
language_df = pd.read_csv(path)
language_df.head(10)
# Out:
# C:\Users\rushi\anaconda3\envs\pythondata\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (15,16,17,25,30,38,41,63,92,99,100,103,110,111,112,113,114,115,116,117,119,121,122,123,126,128,129,132,133,135,137,144,145,146,156,157,158,160,161,163,164,165,166,167,168,169,171,174,175,176,178,179,180,185,186,188,189,190,191,192,196,198,202,203,204,206,207,208,209,210,211,212,213,214,216,217,218,219,220,221,222,223,224,225,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,255,256,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         title  appeared                type      pldbId  rank  languageRank  \
# 0         SQL      1974       queryLanguage         sql     4           4.0
# 1  JavaScript      1995                  pl  javascript     1           1.0
# 2        HTML      1991          textMarkup        html     6           5.0
# 3        Java      1995                  pl        java     0           0.0
# 4         C++      1985                  pl         cpp     5           6.0
# 5           C      1972                  pl           c     2           2.0
# 6       Linux      1991                  os       linux     7           NaN
# 7         CSS      1996  stylesheetLanguage         css    17          19.0
# 8      Python      1991                  pl      python     3           3.0
# 9      MATLAB      1984                  pl      matlab    11          10.0
#
#    factCount  lastActivity  exampleCount  bookCount  ...  features.hasIds  \
# 0        324          2022             6        182  ...              NaN
# 1        818          2022            54        351  ...              NaN
# 2        274          2022             6        116  ...              NaN
# 3        920          2022            20        401  ...              NaN
# 4        461          2022            34        128  ...              NaN
# 5        426          2022            26         78  ...              NaN
# 6         27          2018             0          2  ...              NaN
# 7        261          2018             8        102  ...              NaN
# 8        691          2022            35        342  ...              NaN
# 9        359          2022            11        177  ...              NaN
#
#    ebook  features.hasExports  features.hasZippers features.hasMonads  \
# 0    NaN                  NaN                  NaN                NaN
# 1    NaN                  NaN                  NaN                NaN
# 2    NaN                  NaN                  NaN                NaN
# 3    NaN                  NaN                  NaN                NaN
# 4    NaN                  NaN                  NaN                NaN
# 5    NaN                  NaN                  NaN                NaN
# 6    NaN                  NaN                  NaN                NaN
# 7    NaN                  NaN                  NaN                NaN
# 8    NaN                  NaN                  NaN                NaN
# 9    NaN                  NaN                  NaN                NaN
#
#   extensionOf zulip features.hasImplicitArguments features.hasDynamicTyping  \
# 0         NaN   NaN                           NaN                       NaN
# 1         NaN   NaN                           NaN                      True
# 2         NaN   NaN                           NaN                       NaN
# 3         NaN   NaN                           NaN                       NaN
# 4         NaN   NaN                           NaN                       NaN
# 5         NaN   NaN                           NaN                       NaN
# 6         NaN   NaN                           NaN                       NaN
# 7         NaN   NaN                           NaN                       NaN
# 8         NaN   NaN                           NaN                       NaN
# 9         NaN   NaN                           NaN                       NaN
#
#   features.hasMethodChaining
# 0                        NaN
# 1                       True
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
#
# [10 rows x 353 columns]

# %%
#filterout data between year 1940-2023
filtered_df = language_df[(language_df['appeared'] >= 1940) & (language_df['appeared'] <= 2023)]
filtered_df
# Out:
#            title  appeared           type      pldbId  rank  languageRank  \
# 0            SQL      1974  queryLanguage         sql     4           4.0
# 1     JavaScript      1995             pl  javascript     1           1.0
# 2           HTML      1991     textMarkup        html     6           5.0
# 3           Java      1995             pl        java     0           0.0
# 4            C++      1985             pl         cpp     5           6.0
# ...          ...       ...            ...         ...   ...           ...
# 4813      Gaiman      2022             pl      gaiman  4169        3432.0
# 4814     Peridot      2022             pl     peridot  4192        3455.0
# 4815  SuperForth      2022             pl  superforth  4239        3502.0
# 4816        MiKe      2022             pl        mike  4643        3903.0
# 4817      Qunity      2022             pl      qunity  4789        4046.0
#
#       factCount  lastActivity  exampleCount  bookCount  ...  features.hasIds  \
# 0           324          2022             6        182  ...              NaN
# 1           818          2022            54        351  ...              NaN
# 2           274          2022             6        116  ...              NaN
# 3           920          2022            20        401  ...              NaN
# 4           461          2022            34        128  ...              NaN
# ...         ...           ...           ...        ...  ...              ...
# 4813          7          2022             0          0  ...              NaN
# 4814          7          2022             0          0  ...              NaN
# 4815          7          2022             0          0  ...              NaN
# 4816          8          2022             0          0  ...              NaN
# 4817          8          2022             0          0  ...              NaN
#
#       ebook  features.hasExports  features.hasZippers features.hasMonads  \
# 0       NaN                  NaN                  NaN                NaN
# 1       NaN                  NaN                  NaN                NaN
# 2       NaN                  NaN                  NaN                NaN
# 3       NaN                  NaN                  NaN                NaN
# 4       NaN                  NaN                  NaN                NaN
# ...     ...                  ...                  ...                ...
# 4813    NaN                  NaN                  NaN                NaN
# 4814    NaN                  NaN                  NaN                NaN
# 4815    NaN                  NaN                  NaN                NaN
# 4816    NaN                  NaN                  NaN                NaN
# 4817    NaN                  NaN                  NaN                NaN
#
#      extensionOf zulip features.hasImplicitArguments  \
# 0            NaN   NaN                           NaN
# 1            NaN   NaN                           NaN
# 2            NaN   NaN                           NaN
# 3            NaN   NaN                           NaN
# 4            NaN   NaN                           NaN
# ...          ...   ...                           ...
# 4813         NaN   NaN                           NaN
# 4814         NaN   NaN                           NaN
# 4815         NaN   NaN                           NaN
# 4816         NaN   NaN                           NaN
# 4817         NaN   NaN                           NaN
#
#      features.hasDynamicTyping features.hasMethodChaining
# 0                          NaN                        NaN
# 1                         True                       True
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 4813                       NaN                        NaN
# 4814                       NaN                        NaN
# 4815                       NaN                        NaN
# 4816                       NaN                        NaN
# 4817                       NaN                        NaN
#
# [4780 rows x 353 columns]

# %%
#create newdataframe with only targeted data columns
df = filtered_df[['title','appeared','rank','numberOfUsers','numberOfJobs','githubBigQuery.repos']]
df.head()
# Out:
#         title  appeared  rank  numberOfUsers  numberOfJobs  \
# 0         SQL      1974     4        7179119        219617
# 1  JavaScript      1995     1        5962666         63993
# 2        HTML      1991     6        5570873         69531
# 3        Java      1995     0        5550123         85206
# 4         C++      1985     5        4128238         61098
#
#    githubBigQuery.repos
# 0                 641.0
# 1             1099879.0
# 2              777550.0
# 3              369548.0
# 4              277733.0

# %%
#rename columns 
new_df = df.rename(columns ={'title':'Programming_Language','appeared':'Year','rank':'Rank','numberOfUsers':'Number_Of_Users','numberOfJobs':'Number_Of_Jobs','githubBigQuery.repos':'GitHubBigQuery_Repos'})
new_df.head()
# Out:
#   Programming_Language  Year  Rank  Number_Of_Users  Number_Of_Jobs  \
# 0                  SQL  1974     4          7179119          219617
# 1           JavaScript  1995     1          5962666           63993
# 2                 HTML  1991     6          5570873           69531
# 3                 Java  1995     0          5550123           85206
# 4                  C++  1985     5          4128238           61098
#
#    GitHubBigQuery_Repos
# 0                 641.0
# 1             1099879.0
# 2              777550.0
# 3              369548.0
# 4              277733.0

# %%
#fill nan values with 0
clean_df = new_df.fillna(0)
clean_df.head()
# Out:
#   Programming_Language  Year  Rank  Number_Of_Users  Number_Of_Jobs  \
# 0                  SQL  1974     4          7179119          219617
# 1           JavaScript  1995     1          5962666           63993
# 2                 HTML  1991     6          5570873           69531
# 3                 Java  1995     0          5550123           85206
# 4                  C++  1985     5          4128238           61098
#
#    GitHubBigQuery_Repos
# 0                 641.0
# 1             1099879.0
# 2              777550.0
# 3              369548.0
# 4              277733.0

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4817
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Programming_Language  4780 non-null   object
#  1   Year                  4780 non-null   int64
#  2   Rank                  4780 non-null   int64
#  3   Number_Of_Users       4780 non-null   int64
#  4   Number_Of_Jobs        4780 non-null   int64
#  5   GitHubBigQuery_Repos  4780 non-null   float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 261.4+ KB

# %%
clean_df['GitHubBigQuery_Repos']=clean_df['GitHubBigQuery_Repos'].astype(int)
clean_df
# Out:
#      Programming_Language  Year  Rank  Number_Of_Users  Number_Of_Jobs  \
# 0                     SQL  1974     4          7179119          219617
# 1              JavaScript  1995     1          5962666           63993
# 2                    HTML  1991     6          5570873           69531
# 3                    Java  1995     0          5550123           85206
# 4                     C++  1985     5          4128238           61098
# ...                   ...   ...   ...              ...             ...
# 4813               Gaiman  2022  4169                0               0
# 4814              Peridot  2022  4192                0               0
# 4815           SuperForth  2022  4239                0               0
# 4816                 MiKe  2022  4643                0               0
# 4817               Qunity  2022  4789                0               0
#
#       GitHubBigQuery_Repos
# 0                      641
# 1                  1099879
# 2                   777550
# 3                   369548
# 4                   277733
# ...                    ...
# 4813                     0
# 4814                     0
# 4815                     0
# 4816                     0
# 4817                     0
#
# [4780 rows x 6 columns]

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4780 entries, 0 to 4817
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Programming_Language  4780 non-null   object
#  1   Year                  4780 non-null   int64
#  2   Rank                  4780 non-null   int64
#  3   Number_Of_Users       4780 non-null   int64
#  4   Number_Of_Jobs        4780 non-null   int64
#  5   GitHubBigQuery_Repos  4780 non-null   int32
# dtypes: int32(1), int64(4), object(1)
# memory usage: 242.7+ KB

# %%
# Convert Pandas DataFrame To JSON Using orient = 'records' 
df2 = clean_df.to_json(orient = 'records')
print(df2)
# Out:
# [{"Programming_Language":"SQL","Year":1974,"Rank":4,"Number_Of_Users":7179119,"Number_Of_Jobs":219617,"GitHubBigQuery_Repos":641},{"Programming_Language":"JavaScript","Year":1995,"Rank":1,"Number_Of_Users":5962666,"Number_Of_Jobs":63993,"GitHubBigQuery_Repos":1099879},{"Programming_Language":"HTML","Year":1991,"Rank":6,"Number_Of_Users":5570873,"Number_Of_Jobs":69531,"GitHubBigQuery_Repos":777550},{"Programming_Language":"Java","Year":1995,"Rank":0,"Number_Of_Users":5550123,"Number_Of_Jobs":85206,"GitHubBigQuery_Repos":369548},{"Programming_Language":"C++","Year":1985,"Rank":5,"Number_Of_Users":4128238,"Number_Of_Jobs":61098,"GitHubBigQuery_Repos":277733},{"Programming_Language":"C","Year":1972,"Rank":2,"Number_Of_Users":3793768,"Number_Of_Jobs":59919,"GitHubBigQuery_Repos":292876},{"Programming_Language":"Linux","Year":1991,"Rank":7,"Number_Of_Users":3229009,"Number_Of_Jobs":32007,"GitHubBigQuery_Repos":0},{"Programming_Language":"CSS","Year":1996,"Rank":17,"Number_Of_Users":2881846,"Number_Of_Jobs":45617,"GitHubBigQuery_Repos":808537},{"Programming_Language":"Python","Year":1991,"Rank":3,"Number_Of_Users":2818037,"Number_Of_Jobs":46976,"GitHubBigQuery_Repos":550171},{"Programming_Language":"MATLAB","Year":1984,"Rank":11,"Number_Of_Users":2661579,"Number_Of_Jobs":32228,"GitHubBigQuery_Repos":2791},{"Programming_Language":"MySQL","Year":1995,"Rank":15,"Number_Of_Users":2608362,"Number_Of_Jobs":47466,"GitHubBigQuery_Repos":0},{"Programming_Language":"PHP","Year":1995,"Rank":9,"Number_Of_Users":2356101,"Number_Of_Jobs":30349,"GitHubBigQuery_Repos":339509},{"Programming_Language":"XML","Year":1996,"Rank":8,"Number_Of_Users":1917452,"Number_Of_Jobs":42277,"GitHubBigQuery_Repos":2700},{"Programming_Language":"JQuery","Year":2006,"Rank":48,"Number_Of_Users":1553841,"Number_Of_Jobs":24780,"GitHubBigQuery_Repos":0},{"Programming_Language":"WordPress","Year":2003,"Rank":63,"Number_Of_Users":1350482,"Number_Of_Jobs":14952,"GitHubBigQuery_Repos":0},{"Programming_Language":"R","Year":1993,"Rank":18,"Number_Of_Users":1075613,"Number_Of_Jobs":14173,"GitHubBigQuery_Repos":29347},{"Programming_Language":"Android","Year":2008,"Rank":14,"Number_Of_Users":975958,"Number_Of_Jobs":9263,"GitHubBigQuery_Repos":0},{"Programming_Language":"SPSS","Year":1968,"Rank":107,"Number_Of_Users":965674,"Number_Of_Jobs":9587,"GitHubBigQuery_Repos":0},{"Programming_Language":"Git","Year":2005,"Rank":79,"Number_Of_Users":714200,"Number_Of_Jobs":7032,"GitHubBigQuery_Repos":0},{"Programming_Language":"iOS","Year":2007,"Rank":20,"Number_Of_Users":535588,"Number_Of_Jobs":5010,"GitHubBigQuery_Repos":0},{"Programming_Language":"Arduino Programming Language","Year":2005,"Rank":29,"Number_Of_Users":527398,"Number_Of_Jobs":598,"GitHubBigQuery_Repos":20461},{"Programming_Language":"Go","Year":2009,"Rank":21,"Number_Of_Users":525179,"Number_Of_Jobs":6403,"GitHubBigQuery_Repos":91470},{"Programming_Language":"Perl","Year":1987,"Rank":10,"Number_Of_Users":491984,"Number_Of_Jobs":13482,"GitHubBigQuery_Repos":101542},{"Programming_Language":"TensorFlow","Year":2015,"Rank":243,"Number_Of_Users":435167,"Number_Of_Jobs":721,"GitHubBigQuery_Repos":0},{"Programming_Language":"Node.js","Year":2009,"Rank":40,"Number_Of_Users":374143,"Number_Of_Jobs":6864,"GitHubBigQuery_Repos":0},{"Programming_Language":"Swift","Year":2014,"Rank":23,"Number_Of_Users":362590,"Number_Of_Jobs":3754,"GitHubBigQuery_Repos":42531},{"Programming_Language":"SAS","Year":1976,"Rank":34,"Number_Of_Users":361103,"Number_Of_Jobs":4682,"GitHubBigQuery_Repos":1350},{"Programming_Language":"Ruby","Year":1995,"Rank":12,"Number_Of_Users":357730,"Number_Of_Jobs":11438,"GitHubBigQuery_Repos":374367},{"Programming_Language":"JSON","Year":2001,"Rank":19,"Number_Of_Users":355741,"Number_Of_Jobs":9228,"GitHubBigQuery_Repos":6},{"Programming_Language":"PostgreSQL","Year":1986,"Rank":27,"Number_Of_Users":340751,"Number_Of_Jobs":13084,"GitHubBigQuery_Repos":0},{"Programming_Language":"MongoDB","Year":2009,"Rank":56,"Number_Of_Us ...

# %%
# specify the file path where you want to save the  data
json_path = '../static/data.json'

# write the string to a file using the json.dump method
with open(json_path, 'w') as f:
    json.dump(df2, f)

# %%
engine = create_engine("postgresql://postgres:!Cricket07@localhost:5433/Programming_language")
connection = engine.connect()
clean_df.to_sql("programming_language", connection, if_exists="replace")
